# %%
import xmltodict, json
import pandas_read_xml as pdx
import pandas as pd
import numpy as np
from collections import OrderedDict
import xml.etree.ElementTree as ET
import random

# %%
# count number of dictionary having the same key in a list of dictionaries
def count_key(list_of_dict, key):
    return sum(1 for d in list_of_dict if key in d)

# %%
with open('dump.xml', 'r') as file:
    obj = xmltodict.parse(file.read())
    
# raw_data = json.dumps(obj)
# data = json.loads(raw_data)
with open('data.json', 'w', encoding='utf-8') as f:
    json.dump(obj, f, ensure_ascii=False, indent=4)

print(data['netstate']['timestep'][-1])
last_time = data['netstate']['timestep'][-1]

df = DataFrame(last_time)
df

# %%
with open("data.json") as datafile:

# %%
json = pd.read_json("data.json")
data = json.netstate.timestep[-1]
print("Count edge", count_key(data["edge"], "@id"))
print("Type Edge:", type(data["edge"]))

print("Count Lane", count_key(data["edge"]["lane"], "@id"))
print("Type Lane:", type(data["edge"]["lane"]))

print("Count VehicleID", count_key(data["edge"]["lane"][0], "@id"))
print("Type VehicleID:", type(data["edge"]["lane"][0]))

# %%
# 
if isinstance(data["edge"], dict) and count_key(data["edge"], '@id')==1:
    if isinstance(data["edge"]["lane"], dict) and count_key(data["edge"]["lane"], '@id')==1:
        if isinstance(data["edge"]["lane"]['vehicle'], dict) and count_key(data["edge"]["lane"]['vehicle'], '@id')==1:
            print("Edge,Lane,Vehicle only 1")
            print("EdgeID: ", data["edge"]["@id"])
            print("LaneID: ", data["edge"]["lane"]["@id"])
            print("vehicleID: ", data["edge"]["lane"]["vehicle"]["@id"])
        else:
            for vehicle in range(count_key(data["edge"]["lane"]['vehicle'], '@id')):
                print("Edge,Lane only 1 but Vehicle multiple and this is {}".format(vehicle))
    else:
        for lane in range(count_key(data["edge"]["lane"], '@id')):
            for vehicle in range(count_key(data["edge"]["lane"][lane]['vehicle'], '@id')):
    
else:
    pass

# %%
tree = ET.parse('dump.xml')
root = tree.getroot()
#print(root.tag, root.attrib)
last_time_step = str(root[len(root)-1].attrib['time'])
# print("Last time:",last_time_step)
# print(type(last_time_step))
dataFrame1 = pd.DataFrame(columns=['time', 'carID', 'edgeID', 'laneID', 'pos', 'speed'])
for time in root:
#     print(time.attrib['time'])
    for child in time: #root[len(root)-1]:
        for child2 in child:
            #print(child2)
            #print(f"Lane:{child2.tag}, {child2.attrib}")
            for child3 in child2:
                #print(f"Edge:{child.attrib['id']}, Lane:{child2.attrib['id']}, Vehicle: {child3.attrib}")
                #print(type(child3.attrib))
                #print(child3.attrib['id'])
                dict = {'time'   : str(time.attrib['time']), #last_time_step),
                        'carID'  : str(child3.attrib['id']),
                        'edgeID' : str(child.attrib['id']),
                        'laneID' : str(child2.attrib['id']),
                        'pos'    : str(child3.attrib['pos']),
                        'speed'  : str(child3.attrib['speed'])}
                temp_df = pd.DataFrame([dict])
                #display(temp_df)
                #print(type(dataFrame1))
                dataFrame1 = pd.concat([dataFrame1,temp_df], ignore_index=True, keys=['time', 'carID'])
            


dataFrame0 = dataFrame1.sort_values(['time','carID']).reset_index(drop=True)
display(dataFrame0)

# for child in root:
#     print(child.tag, child.attrib)

# %%
tree = ET.parse('tripinfo.xml')
root = tree.getroot()

dataFrame1 = pd.DataFrame(columns=['carID', 'depart', 'departLane', 'departPos', 'departSpeed', 'departDelay','arrival','arrivalLane','arrivalPos','arrivalSpeed','duration','routeLength','waitingTime','rerouteNo','speedFactor','vaporized'])
for tripinfo in root:
    dict = {'carID':tripinfo.attrib['id'],
            'depart':tripinfo.attrib['depart'],
            'departLane':tripinfo.attrib['departLane'],
            'departPos':tripinfo.attrib['departPos'],
            'departSpeed':tripinfo.attrib['departSpeed'],
            'departDelay':tripinfo.attrib['departDelay'],
            'arrival':tripinfo.attrib['arrival'],
            'arrivalLane':tripinfo.attrib['arrivalLane'],
            'arrivalPos':tripinfo.attrib['arrivalPos'],
            'arrivalSpeed':tripinfo.attrib['arrivalSpeed'],
            'duration':tripinfo.attrib['duration'],
            'routeLength':tripinfo.attrib['routeLength'],
            'waitingTime':tripinfo.attrib['waitingTime'],
            'rerouteNo':tripinfo.attrib['rerouteNo'],
            'speedFactor':tripinfo.attrib['speedFactor'],
            'vaporized':tripinfo.attrib['vaporized']
            }
    temp_df = pd.DataFrame([dict])
    dataFrame1 = pd.concat([dataFrame1,temp_df], ignore_index=True)

dataFrame1 = dataFrame1.sort_values(['carID']).reset_index(drop=True)

df_dump = dataFrame0 
df_tripinfo = dataFrame1

df_concat = pd.merge(df_dump, df_tripinfo, on='carID')
display(df_concat)

# dataFrame2 = pd.concat([dataFrame0, dataFrame1], keys=['carID'], ignore_index=True)
# display(dataFrame2)

# filter1 = dataFrame0['carID']=='car0'
# dataFrameNew = dataFrame0[filter1]
# dataFrameNew.loc[:,'departLane']= 5
# display(dataFrameNew)

# %%
display(dataFrame0)

# %%
read_csv = pd.read_csv('simulationStats.csv')
#read_csv.tail(20)
display(read_csv[read_csv['time']==271.00])

# %%
def concat_list_element_in_double_quotes(datalist):
    return ' '.join(['{}'.format(item) for item in datalist])

datalist = ['E0', 'E1', 'E2', 'E3', 'E4']

datalist2 = concat_list_element_in_double_quotes(datalist)
print(datalist2)

# %%
read_csv = pd.read_csv('simulationStats.csv')
#read_csv.loc[(read_csv['time']==99.00) & (read_csv['carID']=='car9'), "pos"].array[0]

display(read_csv.loc[read_csv['time']==99.0])

# %%
tree_d = ET.parse('dump.xml')
root_d = tree_d.getroot()

dataFrame1 = pd.DataFrame(columns=['time', 'carID', 'edgeID', 'laneID', 'pos', 'speed'])
for time in root_d:
    print("Time:", time)
    if time[0].attrib:
        print('True')
    else:
        print('False')
    for child in time:
        print("Child:", child)
        for child2 in child:
            print("Child2:", child2)
            for child3 in child2:
                if child3.attrib:
                    pass #print(child3.attrib)
                else:
                    pass #print('False')
# Out:
# Time: <Element 'timestep' at 0x0000021F9AA70F40>
# True
# Child: <Element 'edge' at 0x0000021F9AA70D60>
# Child2: <Element 'lane' at 0x0000021F9AA71850>
# Child2: <Element 'lane' at 0x0000021F9AA719E0>
# Time: <Element 'timestep' at 0x0000021F9AA71710>
# True
# Child: <Element 'edge' at 0x0000021F9AA70D10>
# Child2: <Element 'lane' at 0x0000021F9AA71260>
# Child2: <Element 'lane' at 0x0000021F9AA70DB0>
# Time: <Element 'timestep' at 0x0000021F9AA70900>
# True
# Child: <Element 'edge' at 0x0000021F9AA708B0>
# Child2: <Element 'lane' at 0x0000021F9AA70FE0>
# Child2: <Element 'lane' at 0x0000021F9AA70B80>
# Time: <Element 'timestep' at 0x0000021F9AA70BD0>
# True
# Child: <Element 'edge' at 0x0000021F9AA710D0>
# Child2: <Element 'lane' at 0x0000021F9AA71490>
# Child2: <Element 'lane' at 0x0000021F9AA70EA0>
# Time: <Element 'timestep' at 0x0000021F9AA70E50>
# True
# Child: <Element 'edge' at 0x0000021F9AA706D0>
# Child2: <Element 'lane' at 0x0000021F9AA701D0>
# Child2: <Element 'lane' at 0x0000021F9AA70C20>
# Time: <Element 'timestep' at 0x0000021F9AA70A40>
# True
# Child: <Element 'edge' at 0x0000021F9AA70AE0>
# Child2: <Element 'lane' at 0x0000021F9AA71120>
# Child2: <Element 'lane' at 0x0000021F9AA70310>
# Time: <Element 'timestep' at 0x0000021F9AA704A0>
# True
# Child: <Element 'edge' at 0x0000021F9AA702C0>
# Child2: <Element 'lane' at 0x0000021F9AA70680>
# Child2: <Element 'lane' at 0x0000021F9AA70950>
# Time: <Element 'timestep' at 0x0000021F9AA70860>
# True
# Child: <Element 'edge' at 0x0000021F9AA70090>
# Child2: <Element 'lane' at 0x0000021F9AA703B0>
# Child2: <Element 'lane' at 0x0000021F9AA72AC0>
# Time: <Element 'timestep' at 0x0000021F9AA72E30>
# True
# Child: <Element 'edge' at 0x0000021F9AA70130>
# Child2: <Element 'lane' at 0x0000021F9AA70450>
# Child2: <Element 'lane' at 0x0000021F9AA71D00>
# Time: <Element 'timestep' at 0x0000021F9AA73D30>
# True
# Child: <Element 'edge' at 0x0000021F9AA735B0>
# Child2: <Element 'lane' at 0x0000021F9AA71AD0>
# Child2: <Element 'lane' at 0x0000021F9AA73010>
# Time: <Element 'timestep' at 0x0000021F9AA736F0>
# True
# Child: <Element 'edge' at 0x0000021F9AA71A30>
# Child2: <Element 'lane' at 0x0000021F9AA71B20>
# Child2: <Element 'lane' at 0x0000021F9AA733D0>
# Time: <Element 'timestep' at 0x0000021F9AA737E0>
# True
# Child: <Element 'edge' at 0x0000021F9AA73470>
# Child2: <Element 'lane' at 0x0000021F9AA71A80>
# Child2: <Element 'lane' at 0x0000021F9AA725C0>
# Time: <Element 'timestep' at 0x0000021F9AA71E40>
# True
# Child: <Element 'edge' at 0x0000021F9AA73AB0>
# Child2: <Element 'lane' at 0x0000021F9AA73BA0>
# Child2: <Element 'lane' at 0x0000021F9AA73A10>
# Time: <Element 'timestep' at 0x0000021F9AA72020>
# True
# Child: <Element 'edge' at 0x0000021F9AA71F30>
# Child2: <Element 'lane' at 0x0000021F9AA71E90>
# Child2: <Element 'lane' at 0x0000021F9AA73DD0>
# Time: <Element 'timestep' at 0x0000021F9AA728E0>
# True
# Child: <Element 'edge' at 0x0000021F9AA72250>
# Child2: <Element 'lane' at 0x0000021F9AA72FC0>
# Child2: <Element 'lane' at 0x0000021F9AAC9AD0>
# Time: <Element 'timestep' at 0x0000021F9AAC9DF0>
# True
# Child: <Element 'edge' at 0x0000021F9AAC9BC0>
# Child2: <Element 'lane' at 0x0000021F9AAC9D50>
# Child2: <Element 'lane' at 0x0000021F9AAC9C60>
# Time: <Element 'timestep' at 0x0000021F9AAC9F80>
# True
# Child: <Element 'edge' at 0x0000021F9AACA390>
# Child2: <Element 'lane' at 0x0000021F9AACA6B0>
# Child2: <Element 'lane' at 0x0000021F9AACA520>
# Time: <Element 'timestep' at 0x0000021F9AACA4D0>
# True
# Child: <Element 'edge' at 0x0000021F9AACA2F0>
# Child2: <Element 'lane' at 0x0000021F9AACA200>
# Child2: <Element 'lane' at 0x0000021F9AACA430>
# Time: <Element 'timestep' at 0x0000021F9AACAAC0>
# True
# Child: <Element 'edge' at 0x0000021F9AACA7A0>
# Child2: <Element 'lane' at 0x0000021F9AACA980>
# Child2: <Element 'lane' at 0x0000021F9AAD6570>
# Time: <Element 'timestep' at 0x0000021F9AAD7790>
# True
# Child: <Element 'edge' at 0x0000021F9AAD7EC0>
# Child2: <Element 'lane' at 0x0000021F9AAD7BF0>
# Child2: <Element 'lane' at 0x0000021F9AAD7FB0>
# Time: <Element 'timestep' at 0x0000021F9AAD6750>
# True
# Child: <Element 'edge' at 0x0000021F9AAD7510>
# Child2: <Element 'lane' at 0x0000021F9AAD6340>
# Child2: <Element 'lane' at 0x0000021F9AAD5A30>
# Time: <Element 'timestep' at 0x0000021F9AAD4400>
# True
# Child: <Element 'edge' at 0x0000021F9AAD4720>
# Child2: <Element 'lane' at 0x0000021F9AAD4FE0>
# Child2: <Element 'lane' at 0x0000021F9AAD4590>
# Time: <Element 'timestep' at 0x0000021F9AAD4F40>
# True
# Child: <Element 'edge' at 0x0000021F9AAD4C70>
# Child2: <Element 'lane' at 0x0000021F9AAD5580>
# Child2: <Element 'lane' at 0x0000021F9AAD42C0>
# Time: <Element 'timestep' at 0x0000021F9AAD4E50>
# True
# Child: <Element 'edge' at 0x0000021F9AAD4AE0>
# Child2: <Element 'lane' at 0x0000021F9AAD44F0>
# Child2: <Element 'lane' at 0x0000021F9AAD43B0>
# Time: <Element 'timestep' at 0x0000021F9AAD4A90>
# True
# Child: <Element 'edge' at 0x0000021F9AAD45E0>
# Child2: <Element 'lane' at 0x0000021F9AAD4090>
# Child2: <Element 'lane' at 0x0000021F9AAEC680>
# Time: <Element 'timestep' at 0x0000021F9AAED620>
# True
# Child: <Element 'edge' at 0x0000021F9AAEF510>
# Child2: <Element 'lane' at 0x0000021F9AAEFC40>
# Child2: <Element 'lane' at 0x0000021F9AAEC860>
# Time: <Element 'timestep' at 0x0000021F9AAEC270>
# True
# Child: <Element 'edge' at 0x0000021F9AAECC70>
# Child2: <Element 'lane' at 0x0000021F9AAEE660>
# Child2: <Element 'lane' at 0x0000021F9ABC8680>
# Time: <Element 'timestep' at 0x0000021F9ABC8770>
# True
# Child: <Element 'edge' at 0x0000021F9ABC8720>
# Child2: <Element 'lane' at 0x0000021F9ABC87C0>
# Child2: <Element 'lane' at 0x0000021F9ABC8B30>
# Time: <Element 'timestep' at 0x0000021F9ABC88B0>
# True
# Child: <Element 'edge' at 0x0000021F9ABC8860>
# Child2: <Element 'lane' at 0x0000021F9ABC8C70>
# Child2: <Element 'lane' at 0x0000021F9ABC9030>
# Time: <Element 'timestep' at 0x0000021F9ABC8FE0>
# True
# Child: <Element 'edge' at 0x0000021F9ABC90D0>
# Child2: <Element 'lane' at 0x0000021F9ABC9080>
# Child2: <Element 'lane' at 0x0000021F9ABC93F0>
# Time: <Element 'timestep' at 0x0000021F9ABC9210>
# True
# Child: <Element 'edge' at 0x0000021F9ABC91C0>
# Child2: <Element 'lane' at 0x0000021F9ABC9530>
# Child2: <Element 'lane' at 0x0000021F9ABC98F0>
# Time: <Element 'timestep' at 0x0000021F9ABC9710>
# True
# Child: <Element 'edge' at 0x0000021F9ABC96C0>
# Child2: <Element 'lane' at 0x0000021F9ABC9A30>
# Child2: <Element 'lane' at 0x0000021F9ABC9DA0>
# Time: <Element 'timestep' at 0x0000021F9ABC9C60>
# True
# Child: <Element 'edge' at 0x0000021F9ABC9DF0>
# Child2: <Element 'lane' at 0x0000021F9ABC9C10>
# Child2: <Element 'lane' at 0x0000021F9ABCA200>
# Time: <Element 'timestep' at 0x0000021F9ABCA160>
# True
# Child: <Element 'edge' at 0x0000021F9ABCA250>
# Child2: <Element 'lane' at 0x0000021F9ABCA110>
# Child2: <Element 'lane' at 0x0000021F9ABCA610>
# Time: <Element 'timestep' at 0x0000021F9ABCA4D0>
# True
# Child: <Element 'edge' at 0x0000021F9ABCA480>
# Child2: <Element 'lane' at 0x0000021F9ABCA750>
# Child2: <Element 'lane' at 0x0000021F9ABCA840>
# Time: <Element 'timestep' at 0x0000021F9ABCAA20>
# True
# Child: <Element 'edge' at 0x0000021F9ABCAC50>
# Child2: <Element 'lane' at 0x0000021F9ABCACA0>
# Child2: <Element 'lane' at 0x0000021F9ABCB100>
# Time: <Element 'timestep' at 0x0000021F9ABCB150>
# True
# Child: <Element 'edge' at 0x0000021F9ABCB1A0>
# Child2: <Element 'lane' at 0x0000021F9ABCB1F0>
# Child2: <Element 'lane' at 0x0000021F9ABCB600>
# Time: <Element 'timestep' at 0x0000021F9ABCB650>
# True
# Child: <Element 'edge' at 0x0000021F9ABCB6A0>
# Child2: <Element 'lane' at 0x0000021F9ABCB880>
# Child2: <Element 'lane' at 0x0000021F9AB73D30>
# Time: <Element 'timestep' at 0x0000021F9AB72CA0>
# True
# Child: <Element 'edge' at 0x0000021F9AB72E80>
# Child2: <Element 'lane' at 0x0000021F9AB73330>
# Child2: <Element 'lane' at 0x0000021F9AB72C00>
# Time: <Element 'timestep' at 0x0000021F9AB73880>
# True
# Child: <Element 'edge' at 0x0000021F9AB70220>
# Child2: <Element 'lane' at 0x0000021F9AB73010>
# Child2: <Element 'lane' at 0x0000021F9AB73C40>
# Time: <Element 'timestep' at 0x0000021F9AB71300>
# True
# Child: <Element 'edge' at 0x0000021F9AB70EF0>
# Child2: <Element 'lane' at 0x0000021F9AB713A0>
# Child2: <Element 'lane' at 0x0000021F9AB71260>
# Time: <Element 'timestep' at 0x0000021F9AB71A30>
# True
# Child: <Element 'edge' at 0x0000021F9AB71620>
# Child2: <Element 'lane' at 0x0000021F9AB71850>
# Child2: <Element 'lane' at 0x0000021F9AB71CB0>
# Time: <Element 'timestep' at 0x0000021F9AB71120>
# True
# Child: <Element 'edge' at 0x0000021F9AB71530>
# Child2: <Element 'lane' at 0x0000021F9AB715D0>
# Child2: <Element 'lane' at 0x0000021F9AB718F0>
# Time: <Element 'timestep' at 0x0000021F9AB71580>
# True
# Child: <Element 'edge' at 0x0000021F9AB71F30>
# Child2: <Element 'lane' at 0x0000021F9AB71990>
# Child2: <Element 'lane' at 0x0000021F9AB71E40>
# Time: <Element 'timestep' at 0x0000021F9AB72390>
# True
# Child: <Element 'edge' at 0x0000021F9AB71DF0>
# Child2: <Element 'lane' at 0x0000021F9AB72070>
# Child2: <Element 'lane' at 0x0000021F9AB72340>
# Time: <Element 'timestep' at 0x0000021F9AB70A40>
# True
# Child: <Element 'edge' at 0x0000021F9AB70900>
# Child2: <Element 'lane' at 0x0000021F9AB725C0>
# Child2: <Element 'lane' at 0x0000021F9AB70630>
# Time: <Element 'timestep' at 0x0000021F9AB70590>
# True
# Child: <Element 'edge' at 0x0000021F9AB708B0>
# Child2: <Element 'lane' at 0x0000021F9AB72480>
# Child2: <Element 'lane' at 0x0000021F9AB70950>
# Time: <Element 'timestep' at 0x0000021F9AB70F40>
# True
# Child: <Element 'edge' at 0x0000021F9AB70770>
# Child2: <Element 'lane' at 0x0000021F9AB72E30>
# Child2: <Element 'lane' at 0x0000021F9AB553F0>
# Time: <Element 'timestep' at 0x0000021F9AB553A0>
# True
# Child: <Element 'edge' at 0x0000021F9AB55170>
# Child2: <Element 'lane' at 0x0000021F9AB54040>
# Child2: <Element 'lane' at 0x0000021F9AB55B70>
# Time: <Element 'timestep' at 0x0000021F9AB565C0>
# True
# Child: <Element 'edge' at 0x0000021F9AB55620>
# Child2: <Element 'lane' at 0x0000021F9AB555D0>
# Child2: <Element 'lane' at 0x0000021F9AB57830>
# Time: <Element 'timestep' at 0x0000021F9AB57100>
# True
# Child: <Element 'edge' at 0x0000021F9AB56C00>
# Child2: <Element 'lane' at 0x0000021F9AB574C0>
# Child2: <Element 'lane' at 0x0000021F9AB57060>
# Time: <Element 'timestep' at 0x0000021F9AB56A20>
# True
# Child: <Element 'edge' at 0x0000021F9AB56E30>
# Child2: <Element 'lane' at 0x0000021F9AB57010>
# Child2: <Element 'lane' at 0x0000021F9AB57470>
# Time: <Element 'timestep' at 0x0000021F9AB57150>
# True
# Child: <Element 'edge' at 0x0000021F9AB576A0>
# Child2: <Element 'lane' at 0x0000021F9AB57510>
# Child2: <Element 'lane' at 0x0000021F9AB57420>
# Time: <Element 'timestep' at 0x0000021F9AB57F10>
# True
# Child: <Element 'edge' at 0x0000021F9AB57D30>
# Child2: <Element 'lane' at 0x0000021F9AB57560>
# Child2: <Element 'lane' at 0x0000021F9AB57FB0>
# Time: <Element 'timestep' at 0x0000021FF85F5DA0>
# True
# Child: <Element 'edge' at 0x0000021FF85F7D80>
# Child2: <Element 'lane' at 0x0000021F9AA43D30>
# Child2: <Element 'lane' at 0x0000021F9AB658A0>
# Time: <Element 'timestep' at 0x0000021F9AB651C0>
# True
# Child: <Element 'edge' at 0x0000021F9AB65D50>
# Child2: <Element 'lane' at 0x0000021F9AB671A0>
# Child2: <Element 'lane' at 0x0000021F9ABA0770>
# Time: <Element 'timestep' at 0x0000021F9ABA0590>
# True
# Child: <Element 'edge' at 0x0000021F9ABA04F0>
# Child2: <Element 'lane' at 0x0000021F9ABA0540>
# Child2: <Element 'lane' at 0x0000021F9ABA0680>
# Time: <Element 'timestep' at 0x0000021F9ABA06D0>
# True
# Child: <Element 'edge' at 0x0000021F9ABA0720>
# Child2: <Element 'lane' at 0x0000021F9ABA0F40>
# Child2: <Element 'lane' at 0x0000021F9ABA11C0>
# Time: <Element 'timestep' at 0x0000021F9ABA1170>
# True
# Child: <Element 'edge' at 0x0000021F9ABA1210>
# Child2: <Element 'lane' at 0x0000021F9ABA0EF0>
# Child2: <Element 'lane' at 0x0000021F9ABA13F0>
# Time: <Element 'timestep' at 0x0000021F9ABA1490>
# True
# Child: <Element 'edge' at 0x0000021F9ABA1530>
# Child2: <Element 'lane' at 0x0000021F9ABA1620>
# Child2: <Element 'lane' at 0x0000021F9ABA16C0>
# Time: <Element 'timestep' at 0x0000021F9ABA1800>
# True
# Child: <Element 'edge' at 0x0000021F9ABA18F0>
# Child2: <Element 'lane' at 0x0000021F9ABA18A0>
# Child2: <Element 'lane' at 0x0000021F9ABA1A30>
# Time: <Element 'timestep' at 0x0000021F9ABA1B20>
# True
# Child: <Element 'edge' at 0x0000021F9ABA1AD0>
# Child2: <Element 'lane' at 0x0000021F9ABA1B70>
# Child2: <Element 'lane' at 0x0000021F9ABA1D50>
# Time: <Element 'timestep' at 0x0000021F9ABA1E40>
# True
# Child: <Element 'edge' at 0x0000021F9ABA1DF0>
# Child2: <Element 'lane' at 0x0000021F9ABA1EE0>
# Child2: <Element 'lane' at 0x0000021F9ABA1CB0>
# Time: <Element 'timestep' at 0x0000021F9ABA2020>
# True
# Child: <Element 'edge' at 0x0000021F9ABA1C60>
# Child2: <Element 'lane' at 0x0000021F9ABA1C10>
# Child2: <Element 'lane' at 0x0000021F9ABA2340>
# Time: <Element 'timestep' at 0x0000021F9ABA23E0>
# True
# Child: <Element 'edge' at 0x0000021F9ABA22F0>
# Child2: <Element 'lane' at 0x0000021F9ABA2430>
# Child2: <Element 'lane' at 0x0000021F9ABA20C0>
# Time: <Element 'timestep' at 0x0000021F9ABA2070>
# True
# Child: <Element 'edge' at 0x0000021F9ABA25C0>
# Child2: <Element 'lane' at 0x0000021F9ABA2660>
# Child2: <Element 'lane' at 0x0000021F9ABA2840>
# Time: <Element 'timestep' at 0x0000021F9ABA27F0>
# True
# Child: <Element 'edge' at 0x0000021F9ABA2890>
# Child2: <Element 'lane' at 0x0000021F9ABA2570>
# Child2: <Element 'lane' at 0x0000021F9ABA2AC0>
# Time: <Element 'timestep' at 0x0000021F9ABA2A70>
# True
# Child: <Element 'edge' at 0x0000021F9ABA2B60>
# Child2: <Element 'lane' at 0x0000021F9ABA2B10>
# Child2: <Element 'lane' at 0x0000021F9ABA2CF0>
# Time: <Element 'timestep' at 0x0000021F9ABA29D0>
# True
# Child: <Element 'edge' at 0x0000021F9ABA2D40>
# Child2: <Element 'lane' at 0x0000021F9ABA2980>
# Child2: <Element 'lane' at 0x0000021F9ABA2F20>
# Time: <Element 'timestep' at 0x0000021F9ABA2ED0>
# True
# Child: <Element 'edge' at 0x0000021F9ABA2FC0>
# Child2: <Element 'lane' at 0x0000021F9ABA2F70>
# Child2: <Element 'lane' at 0x0000021F9ABA3100>
# Time: <Element 'timestep' at 0x0000021F9ABA30B0>
# True
# Child: <Element 'edge' at 0x0000021F9ABA31A0>
# Child2: <Element 'lane' at 0x0000021F9ABA3150>
# Child2: <Element 'lane' at 0x0000021F9ABA3240>
# Time: <Element 'timestep' at 0x0000021F9ABA2DE0>
# True
# Child: <Element 'edge' at 0x0000021F9ABA2D90>
# Child2: <Element 'lane' at 0x0000021F9ABA3380>
# Child2: <Element 'lane' at 0x0000021F9ABA34C0>
# Time: <Element 'timestep' at 0x0000021F9ABA3470>
# True
# Child: <Element 'edge' at 0x0000021F9ABA3560>
# Child2: <Element 'lane' at 0x0000021F9ABA3510>
# Child2: <Element 'lane' at 0x0000021F9ABA36A0>
# Time: <Element 'timestep' at 0x0000021F9ABA3650>
# True
# Child: <Element 'edge' at 0x0000021F9ABA36F0>
# Child2: <Element 'lane' at 0x0000021F9ABA3330>
# Child2: <Element 'lane' at 0x0000021F9ABA3290>
# Time: <Element 'timestep' at 0x0000021F9ABA3880>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [27], in <cell line: 5>()
#       5 for time in root_d:
#       6     print("Time:", time)
# ----> 7     if time[0].attrib:
#       8         print('True')
#       9     else:
#
# IndexError: child index out of range

# %%
routes = {'route0': ['E0', 'E12', 'E4', 'E7'],
              'route1': ['-E7', '-E4', '-E12', '-E0'],
              'route2': ['-E6', '-E12', 'E2']}
print(type(routes['route2']))

print(random.choice(list(routes.keys())))
# Out:
# <class 'list'>
# route0

# %%
trip_df = pd.read_csv('tripinfo.csv', keep_default_na=False)
display(trip_df.tail(10))
# Out:
#   carID  depart departLane  departPos  departSpeed  departDelay  arrival  \
# 0  car0     0.0      -E6_0      100.0          0.0          0.0     39.0
# 1  car3     4.0      -E6_0      100.0          0.0          1.0     45.0
# 2  car8    10.0      -E6_0      100.0          0.0          2.0     54.0
# 3  car4     4.0      -E7_0      100.0          0.0          0.0    105.0
# 4  car1     1.0       E0_0      100.0          0.0          0.0     -1.0
# 5  car2     6.0       E0_0      100.0          0.0          4.0     -1.0
# 6  car5    11.0       E0_0      100.0          0.0          6.0     -1.0
# 7  car6    16.0       E0_0      100.0          0.0         10.0     -1.0
# 8  car7    21.0       E0_0      100.0          0.0         14.0     -1.0
# 9  car9    26.0       E0_0      100.0          0.0         17.0     -1.0
#
#   arrivalLane  arrivalPos  arrivalSpeed  duration  routeLength  waitingTime  \
# 0        E2_0       100.0         14.61      39.0       400.00          0.0
# 1        E2_0       100.0         14.79      41.0       400.00          1.0
# 2        E2_0       100.0         12.68      44.0       400.00          1.0
# 3       -E0_0       500.0         13.93     101.0      1200.00          0.0
# 4                    -1.0         -1.00     119.0       573.13          2.0
# 5                    -1.0         -1.00     114.0       575.63          0.0
# 6                    -1.0         -1.00     109.0       532.48          0.0
# 7                    -1.0         -1.00     104.0       558.50          0.0
# 8                    -1.0         -1.00      99.0       522.45          0.0
# 9                    -1.0         -1.00      94.0       506.68          0.0
#
#    rerouteNo  speedFactor vaporized
# 0          0         1.06
# 1          0         1.08
# 2          0         0.94
# 3          0         1.03
# 4          0         0.94       end
# 5          0         1.01       end
# 6          0         0.83       end
# 7          0         1.05       end
# 8          0         0.89       end
# 9          0         0.86       end

# %%
df_stats = pd.read_csv('simulationStats.csv', keep_default_na=False)
#display(total_df.tail(40))
df_stats_last_time = df_stats.loc[df_stats['time'] == df_stats['time'].tail(1).tolist()[0]]
display(df_stats_last_time)
carIDs_for_next_simulation = df_stats_last_time['carID'].tolist()
print(carIDs_for_next_simulation)

df_stats_last_time.loc[df_stats_last_time['carID'] == 'car3']['pos'].tolist()[0]
# Out:
#       time carID  depart edgeID departLane laneID arrivalLane  departPos  \
# 407  119.0  car4     8.0    E12       E0_0  E12_0                  100.0
# 408  119.0  car3     3.0    E12       E0_0  E12_1                  100.0
#
#         pos  arrivalPos  ...  speed  arrivalSpeed  departDelay  waitingTime  \
# 407  181.51        -1.0  ...   2.69          -1.0          4.0          0.0
# 408  177.45        -1.0  ...   2.36          -1.0          0.0          0.0
#
#      duration  arrival  routeLength  rerouteNo  speedFactor  vaporized
# 407     112.0     -1.0       581.51          0         1.01        end
# 408     117.0     -1.0       577.45          0         0.94        end
#
# [2 rows x 21 columns]
# ['car4', 'car3']
# 177.45

# %%
    
    
    
    
    
    
    
# print("edge id ", data["edge"]['@id'])
# print("edge len ", len(data.keys()))
# print("lane len ", len(data["edge"]["lane"]))
# print("How many key?:", count_key(data["edge"]["lane"], '@id'))


# print('{} edge!'.format(count_key(data["edge"], '@id')))
# print('{} lane!'.format(count_key(data["edge"]["lane"], '@id')))
# print('{} vehicle!'.format(count_key(data["edge"]["lane"]["vehicle"], '@id') if isinstance(data["edge"]["lane"], dict) else len(data["edge"]["lane"])))

# for edge in range(count_key(data["edge"], '@id') if isinstance(data["edge"], list) else 5):
#      for lane in range(count_key(data["edge"]["lane"], '@id')):
#         #if 'vehicle' in data["edge"]["lane"][lane]:
#         #print("Vehicles: ",count_key(data["edge"]["lane"][lane]['vehicle'], '@id'))
#         print(type(data["edge"]["lane"][lane]['vehicle']))
#         for vehicle in range(count_key(data["edge"]["lane"][lane]['vehicle'], '@id')):
#             print("Lane:", data["edge"]["lane"][lane])
#             print("Vehicle:", data["edge"]["lane"][lane]['vehicle'])
#             print(count_key(data["edge"]["lane"][lane]['vehicle'], '@id'))
#                print(vehicle)
#                 temp=data["edge"]["lane"][lane]
#                 print(temp['vehicle'])
             

                
            #print(type(data["edge"]["lane"][lane]))
            #print(data["edge"]["lane"][lane].values)
            
#         for vehicle in range(len(temp['vehicle'])):
#             print(f'Vehicle on the lane {i}:')
#         del temp
#                 print(data_lane[i]['vehicle'][v])
#                 print(data_lane[i]['vehicle'][v]['@id'], \
#                      'is on position {}'.format(data_lane[i]['vehicle'][v]['@pos']),\
#                      ' and speed {}'.format(data_lane[i]['vehicle'][v]['@speed']))
                
# for net in range(len(data)):
#     print(type(data_1), "Starts here")
#     keys=[] 
#     values=[]
#     for key, value in data.items():
#         keys.append(key)
#         values.append(value)
#     print(f"keys: {keys}, values: {values}")

# print('Len of netstate:', len(data_1))
# data_edge = data['edge']
# data_lane = data_edge['lane']
# print(type(data_edge))
# for key, value in data_edge.items():
#     print(f"key: {key}, value: {value}")

# print('Edge:', len(data_edge))
# for edge in range(len(data_edge)):
#     for i in range(len(data_lane)):
#     #     print('Exist_', len(data_lane[i]))
#         if len(data_lane[i]) >1:
#             print(len(data_lane[i]['vehicle']))
#             for v in range(len(data_lane[i]['vehicle'])):
#                 print(f'Vehicle on the lane {i}:')
#                 print(data_lane[i]['vehicle'][v])
#                 print(data_lane[i]['vehicle'][v]['@id'], \
#                      'is on position {}'.format(data_lane[i]['vehicle'][v]['@pos']),\
#                      ' and speed {}'.format(data_lane[i]['vehicle'][v]['@speed']))

#         else:
#             print(f'No vehicle on the lane {i}')
#     #         print('False')
    
# print("LEN:", len(data_lane))

# print(len(data_lane[0]['vehicle']))
# data_vehicle = []

# bn = pd.DataFrame(data_vehicle)
# pd.DataFrame.from_records(bn).head()

# %%
dataFrame = pdx.read_xml("dump.xml")
print(dataFrame.to_json())

# %%
def parseXmlToJson(xml):
  response = {}

  for child in list(xml):
    if len(list(child)) > 0:
      response[child.tag] = parseXmlToJson(child)
    else:
      response[child.tag] = child.text or ''

    # one-liner equivalent
    # response[child.tag] = parseXmlToJson(child) if len(list(child)) > 0 else child.text or ''

  return response

# %%
xml    = et.parse('dump.xml')
print(type(xml))
xmlroot = xml.getroot()
print(type(xmlroot))
parsed = parseXmlToJson(xmlroot)
print(parsed)

# %%
etree = et.parse('dump.xml')

# %%
etree

# %%
eroot = etree.getroot()

# %%
eroot

# %%
eroot.tag

# %%
temp = eroot.find("netstate")
temp

# %%
def parse_xml(xml):
    attr = xml.attrib
    for elem in xml.findall('netstate'):
        xml_data = attr.copy()
        xml_data.update(elem.attrib)
        xml_data['time']

# %%
data = parse_xml(eroot)

# %%
netstate
    timestep              >> time
        edge              >> edge_id
            lane          >> lane_id  
                vehicle   >> vehicle_id, vehicle_pos, vehicle_speed
